# %%
import numpy as np  # импортируем библиотеку


# число угадывает человек
print('Здравствуйте! Попробуйте угадать число, которое загадал компьютер!')
count = 0                            # счетчик попыток
number = np.random.randint(1, 101)    # загадали число
print ("Загадано число от 1 до 100")
while True:                        # бесконечный цикл
    predict = int(input())         # предполагаемое число
    count += 1                     # плюсуем попытку
    if number == predict: break    # выход из цикла, если угадали
    elif number > predict: print (f"Угадываемое число больше {predict} ")
    elif number < predict: print (f"Угадываемое число меньше {predict} ")
print (f"Неплохо!Вы угадали число {number} за {count} попыток. \n")


# создаем функцию, позволяющую запустить игру 1000 раз
def score_game(game_core):
    count_ls = []
    np.random.seed(1)  # фиксируем RANDOM SEED
    random_array = np.random.randint(1, x+1, size=(1000))  # создаем массив
    for number in random_array:  # находим среднее число попыток
        count_ls.append(game_core(number))
    score = int(np.mean(count_ls))
    print(f"Алгоритм угадывает число от 1 до {x} в среднем за {score} попыток \n")
    return(score)


# создаем функцию, угадывающую любое число
def game_core(number):
    # Сокращаем доступный диапазон вдвое. Начинаем с 50
    predict = lambda x: (x+1) / 2
    predict = int(predict(x))
    count = 1
    if predict == number: return(count)
    else:
        # создаем бесконечный цикл, угадывающий число
        while True:
            if predict == number: break
            elif count < counter(x) and number > predict:
                count += 1
                predict += round(x / 2**count)
            elif count < counter(x) and number < predict:
                count += 1
                predict -= round(x / 2**count)
            else:  # позволяем угадать число x
                count += 1
                predict = predict + 1
    return(count)  # на выходе получаем чило попыток


# функция для нахождения максимального числа попыток
def counter(x):
    for count in range(1, x+1):
        if x - 2**count < 0:
            return count


print('Сейчас, давайте позволим сделать это компьютеру! \nСыграем в игру 1000 раз и увидим среднее число попыток! \n')
x = 100
score_game(game_core)
print('Давайте усложним задание! \nКомпьютер может угадать любое целое число в диапазоне от 1 до Х. \n')


# функция, проверяющая Х
while True:
    x = int(input('Введите положительное число Х: \n'))
    if x > 0: break
    elif x <= 0:
        print('Введите, пожалуйста, положительное число')
score_game(game_core)


print('Спасибо за потраченное время!')
# Out:
# Здравствуйте! Попробуйте угадать число, которое загадал компьютер!
# Загадано число от 1 до 100
# 22
# Угадываемое число больше 22
# 74
# Угадываемое число меньше 74
# 55
# Угадываемое число меньше 55
# 40
# Угадываемое число больше 40
# 47
# Угадываемое число больше 47
# 51
# Угадываемое число меньше 51
# 49
# Угадываемое число меньше 49
# 48
# Неплохо!Вы угадали число 48 за 8 попыток.
#
# Сейчас, давайте позволим сделать это компьютеру!
# Сыграем в игру 1000 раз и увидим среднее число попыток!
#
# Алгоритм угадывает число от 1 до 100 в среднем за 5 попыток
#
# Давайте усложним задание!
# Компьютер может угадать любое целое число в диапазоне от 1 до Х.
#
# Введите положительное число Х:
# 2000
# Алгоритм угадывает число от 1 до 2000 в среднем за 9 попыток
#
# Спасибо за потраченное время!
